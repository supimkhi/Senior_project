# %%
import os
import pandas as pd
from bs4 import BeautifulSoup

# %%
SCORE_DIR = 'data/scores'

# %%
box_scores = os.listdir(SCORE_DIR)

# %%
len(box_scores)
# Out:
# 65

# %%
box_scores = [os.path.join(SCORE_DIR, f) for f in box_scores if f.endswith('.html')]

# %%
box_scores
# Out:
# ['data/scores/199704050CHH.html',
#  'data/scores/199704010MIA.html',
#  'data/scores/199704030IND.html',
#  'data/scores/199704060LAL.html',
#  'data/scores/199704010DAL.html',
#  'data/scores/199704030SEA.html',
#  'data/scores/199704010ORL.html',
#  'data/scores/199704050GSW.html',
#  'data/scores/199704030WSB.html',
#  'data/scores/199704080LAC.html',
#  'data/scores/199704040MIN.html',
#  'data/scores/199704040BOS.html',
#  'data/scores/199704060SAC.html',
#  'data/scores/199704040DEN.html',
#  'data/scores/199704040CHI.html',
#  'data/scores/199704030GSW.html',
#  'data/scores/199704020SAS.html',
#  'data/scores/199704070UTA.html',
#  'data/scores/199704020MIN.html',
#  'data/scores/199704040POR.html',
#  'data/scores/199704080GSW.html',
#  'data/scores/199704050POR.html',
#  'data/scores/199704020BOS.html',
#  'data/scores/199704060NJN.html',
#  'data/scores/199704020CHH.html',
#  'data/scores/199704070DET.html',
#  'data/scores/199704050SEA.html',
#  'data/scores/199704060ORL.html',
#  'data/scores/199704010VAN.html',
#  'data/scores/199704010POR.html',
#  'data/scores/199704060MIN.html',
#  'data/scores/199704040SAC.html',
#  'data/scores/199704060BOS.html',
#  'data/scores/199704070DEN.html',
#  'data/scores/199704080MIL.html',
#  'data/scores/199704070CHI.html',
#  'data/scores/199704060GSW.html',
#  'data/scores/199704020PHI.html',
#  'data/scores/199704020UTA.html',
#  'data/scores/199704040LAL.html',
#  'data/scores/199704070CLE.html',
#  'data/scores/199704010SEA.html',
#  'data/scores/199704030ORL.html',
#  'data/scores/199704030NJN.html',
#  'data/scores/199704040NYK.html',
#  'data/scores/199704010IND.html',
#  'data/scores/199704080DAL.html',
#  'data/scores/199704020LAL.html',
#  'data/scores/199704010CLE.html',
#  'data/scores/199704020PHO.html',
#  'data/scores/199704050MIA.html',
#  'data/scores/199704050ATL.html',
#  'data/scores/199704040ATL.html',
#  'data/scores/199704060VAN.html',
#  'data/scores/199704010DEN.html',
#  'data/scores/199704040PHI.html',
#  'data/scores/199704040UTA.html']

# %%
def parse_html(box_score):
    with open(box_score) as f:
        html = f.read()

        soup = BeautifulSoup(html)
        [s.decompose() for s in soup.select("tr.over_header")]
        [s.decompose() for s in soup.select("tr.thread")]

    return soup

# %%
def read_line_score(soup):
    line_score = pd.read_html(str(soup), attrs={"class": 'section_content'})[0]
    #"id": 'line_score'

# %%
box_score = box_scores[0]
soup = parse_html(box_score)
pd.read_html(str(soup), attrs={"class": 'section_content'})
#pd.read_html(str(soup), attrs={"class": 'line_score'})
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[169], line 3
#       1 box_score = box_scores[0]
#       2 soup = parse_html(box_score)
# ----> 3 pd.read_html(str(soup), attrs={"class": 'section_content'})
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1201 validate_header_arg(header)
#    1203 io = stringify_path(io)
# -> 1205 return _parse(
#    1206     flavor=flavor,
#    1207     io=io,
#    1208     match=match,
#    1209     header=header,
#    1210     index_col=index_col,
#    1211     skiprows=skiprows,
#    1212     parse_dates=parse_dates,
#    1213     thousands=thousands,
#    1214     attrs=attrs,
#    1215     encoding=encoding,
#    1216     decimal=decimal,
#    1217     converters=converters,
#    1218     na_values=na_values,
#    1219     keep_default_na=keep_default_na,
#    1220     displayed_only=displayed_only,
#    1221     extract_links=extract_links,
#    1222 )
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/html.py:982, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     980 retained = None
#     981 for flav in flavor:
# --> 982     parser = _parser_dispatch(flav)
#     983     p = parser(io, compiled_match, attrs, encoding, displayed_only, extract_links)
#     985     try:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/html.py:931, in _parser_dispatch(flavor)
#     929 if flavor in ("bs4", "html5lib"):
#     930     if not _HAS_HTML5LIB:
# --> 931         raise ImportError("html5lib not found, please install it")
#     932     if not _HAS_BS4:
#     933         raise ImportError("BeautifulSoup4 (bs4) not found, please install it")
#
# ImportError: html5lib not found, please install it

# %%
soup
# Out:
# <html><body><h1>Philadelphia 76ers at Charlotte Hornets Box Score, April 5, 1997</h1>
# <div class="section_wrapper" id="all_other_scores">
# <div class="section_heading assoc_other_scores" id="other_scores_sh">
# <span class="section_anchor" data-label="All Games This Date" id="other_scores_link"></span><h2></h2>
# </div><div class="placeholder"></div>
# <!--     <div class="section_content" id="div_other_scores">
# 	    <div class="game_summaries compressed">
#    <h2>NBA Scores &mdash; Apr 5, 1997</h2>
#
#       <div class="game_summary nohover ">
# 	<table class="teams poptip" data-tip="New York Knicks at Atlanta Hawks">
# 		<tbody>
# 		<tr class="winner">
# 			<td><a href="/teams/NYK/1997.html">NYK</a></td>
# 			<td class="right">102</td>
# 			<td class="right gamelink">
# 				<a href="/boxscores/199704050ATL.html">F<span class="no_mobile">inal</span></a>
#
# 			</td>
# 		</tr>
# 		<tr class="loser">
# 			<td><a href="/teams/ATL/1997.html">ATL</a></td>
# 			<td class="right">97</td>
# 			<td class="right">&nbsp;
# 			</td>
# 		</tr>
# 		</tbody>
# 	</table>
#
#
# </div>
#
#       <div class="game_summary nohover current ">
# 	<table class="teams poptip" data-tip="Philadelphia 76ers at Charlotte Hornets">
# 		<tbody>
# 		<tr class="loser">
# 			<td><a href="/teams/PHI/1997.html">PHI</a></td>
# 			<td class="right">113</td>
# 			<td class="right gamelink">
# 				<a href="/boxscores/199704050CHH.html">F<span class="no_mobile">inal</span></a>
#
# 			</td>
# 		</tr>
# 		<tr class="winner">
# 			<td><a href="/teams/CHH/1997.html">CHH</a></td>
# 			<td class="right">115</td>
# 			<td class="right">&nbsp;
# 			</td>
# 		</tr>
# 		</tbody>
# 	</table>
#
#
# </div>
#
#       <div class="game_summary nohover ">
# 	<table class="teams poptip" data-tip="San Antonio Spurs at Golden State Warriors">
# 		<tbody>
# 		<tr class="loser">
# 			<td><a href="/teams/SAS/1997.html">SAS</a></td>
# 			<td class="right">103</td>
# 			<td class="right gamelink">
# 				<a href="/boxscores/199704050GSW.html">F<span class="no_mobile">inal</span></a>
#
# 			</td>
# 		</tr>
# 		<tr class="winner">
# 			<td><a href="/teams/GSW/1997.html">GSW</a></td>
# 			<td class="right">120</td>
# 			<td class="right">&nbsp;
# 			</td>
# 		</tr>
# 		</tbody>
# 	</table>
#
#
# </div>
#
#       <div class="game_summary nohover ">
# 	<table class="teams poptip" data-tip="Toronto Raptors at Miami Heat">
# 		<tbody>
# 		<tr class="loser">
# 			<td><a href="/teams/TOR/1997.html">TOR</a></td>
# 			<td class="right">84</td>
# 			<td class="right gamelink">
# 				<a href="/boxscores/199704050MIA.html">F<span class="no_mobile">inal</span></a>
#
# 			</td>
# 		</tr>
# 		<tr class="winner">
# 			<td><a href="/teams/MIA/1997.html">MIA</a></td>
# 			<td class="right">98</td>
# 			<td class="right">&nbsp;
# 			</td>
# 		</tr>
# 		</tbody>
# 	</table>
#
#
# </div>
#
#       <div class="game_summary nohover ">
# 	<table class="teams poptip" data-tip="Phoenix Suns at Portland Trail Blazers">
# 		<tbody>
# 		<tr class="winner">
# 			<td><a href="/teams/PHO/1997.html">PHO</a></td>
# 			<td class="right">99</td>
# 			<td class="right gamelink">
# 				<a href="/boxscores/199704050POR.html">F<span class="no_mobile">inal</span></a>
#
# 			</td>
# 		</tr>
# 		<tr class="loser">
# 			<td><a href="/teams/POR/1997.html">POR</a></td>
# 			<td class="right">90</td>
# 			<td class="right">&nbsp;
# 			</td>
# 		</tr>
# 		</tbody>
# 	</table>
#
#
# </div>
#
#       <div class="game_summary nohover ">
# 	<table class="teams poptip" data-tip="Dallas Mavericks at Seattle SuperSonics">
# 		<tbody>
# 		<tr class="loser">
# 			<td><a href="/teams/DAL/1997.html">DAL</a></td>
# 			<td class="right">84</td>
# 			<td class="right gamelink">
# 				<a href="/boxscores/199704050SEA.html">F<span class="no_mobile">inal</span></a>
#
# 			</td>
# 		</tr>
# 		<tr class="winner">
# 			<td><a href="/teams/SEA/1997.html">SEA</a></td>
# 			<td class="right">103</td>
# 			<td class="right">&nbsp;
# 			</td>
# 		</tr>
# 		</tbody>
# 	</table>
#
#
# </div>
#
#
# </div>
#
#
#     </div>
# -->
# <div class="section_content" id="div_other_scores">
# <div class="game_summaries compressed">
# <h2>NBA Scores — Apr 5, 1997</h2>
# <div class="game_summary nohover">
# <table class="teams poptip" data-tip="New York Knicks at Atlanta Hawks">
# <tbody>
# <tr class="winner">
# <td><a href="/teams/NYK/1997.html">NYK</a></td>
# <td class="right">102</td>
# <td class="right gamelink">
# <a href="/boxscores/199704050ATL.html">F<span class="no_mobile">inal</span></a>
# </td>
# </tr>
# <tr class="loser">
# <td><a href="/teams/ATL/1997.html">ATL</a></td>
# <td class="right">97</td>
# <td class="right">
# 			</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="game_summary nohover current">
# <table class="teams poptip" data-tip="Philadelphia 76ers at Charlotte Hornets">
# <tbody>
# <tr class="loser">
# <td><a href="/teams/PHI/1997.html">PHI</a></td>
# <td class="right">113</td>
# <td class="right gamelink">
# <a href="/boxscores/199704050CHH.html">F<span class="no_mobile">inal</span></a>
# </td>
# </tr>
# <tr class="winner">
# <td><a href="/teams/CHH/1997.html">CHH</a></td>
# <td class="right">115</td>
# <td class="right">
# 			</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="game_summary nohover">
# <table class="teams poptip" data-tip="San Antonio Spurs at Golden State Warriors">
# <tbody>
# <tr class="loser">
# <td><a href="/teams/SAS/1997.html">SAS</a></td>
# <td class="right">103</td>
# <td class="right gamelink">
# <a href="/boxscores/199704050GSW.html">F<span class="no_mobile">inal</span></a>
# </td>
# </tr>
# <tr class="winner">
# <td><a href="/teams/GSW/1997.html">GSW</a></td>
# <td class="right">120</td>
# <td class="right">
# 			</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="game_summary nohover">
# <table class="teams poptip" data-tip="Toronto Raptors at Miami Heat">
# <tbody>
# <tr class="loser">
# <td><a href="/teams/TOR/1997.html">TOR</a></td>
# <td class="right">84</td>
# <td class="right gamelink">
# <a href="/boxscores/199704050MIA.html">F<span class="no_mobile">inal</span></a>
# </td>
# </tr>
# <tr class="winner">
# <td><a href="/teams/MIA/1997.html">MIA</a></td>
# <td class="right">98</td>
# <td class="right">
# 			</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="game_summary nohover">
# <table class="teams poptip" data-tip="Phoenix Suns at Portland Trail Blazers">
# <tbody>
# <tr class="winner">
# <td><a href="/teams/PHO/1997.html">PHO</a></td>
# <td class="right">99</td>
# <td class="right gamelink">
# <a href="/boxscores/199704050POR.html">F<span class="no_mobile">inal</span></a>
# </td>
# </tr>
# <tr class="loser">
# <td><a href="/teams/POR/1997.html">POR</a></td>
# <td class="right">90</td>
# <td class="right">
# 			</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="game_summary nohover">
# <table class="teams poptip" data-tip="Dallas Mavericks at Seattle SuperSonics">
# <tbody>
# <tr class="loser">
# <td><a href="/teams/DAL/1997.html">DAL</a></td>
# <td class="right">84</td>
# <td class="right gamelink">
# <a href="/boxscores/199704050SEA.html">F<span class="no_mobile">inal</span></a>
# </td>
# </tr>
# <tr class="winner">
# <td><a href="/teams/SEA/1997.html">SEA</a></td>
# <td class="right">103</td>
# <td class="right">
# 			</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="scorebox">
# <div>
# <div>
# <div class="media-item logo">
# <img alt="1997 Philadelphia 76ers Logo" class="teamlogo" src="https://cdn.ssref.net/req/202303071/tlogo/bbr/PHI-1997.png"/>
# <p><a href="http://www.sportslogos.net/">via Sports Logos.net</a></p>
# <p><a href="https://www.sports-reference.com/blog/2016/06/redesign-team-and-league-logos-courtesy-sportslogos-net/">About logos</a></p>
# </div>
# <strong>
# <a href="/teams/PHI/1997.html">Philadelphia 76ers</a>
# </strong>
# </div>
# <div class="scores">
# <div class="score">113</div>
# </div><div>21-53</div>
# <div class="prevnext">
# <a class="button2 prev" href="/boxscores/199704040PHI.html">Prev Game</a>
# <a class="button2 next" href="/boxscores/199704070CHI.html">Next Game</a>
# </div>
# </div>
# <div>
# <div>
# <div class="media-item logo loader">
# <img alt="1997 Charlotte Hornets Logo" class="teamlogo" src="https://cdn.ssref.net/req/202303071/tlogo/bbr/CHH-1997.png"/>
# <p><a href="http://www.sportslogos.net/">via Sports Logos.net</a></p>
# <p><a href="https://www.sports-reference.com/blog/2016/06/redesign-team-and-league-logos-courtesy-sportslogos-net/">About logos</a></p>
# </div>
# <strong>
# <a href="/teams/CHH/1997.html">Charlotte Hornets</a>
# </strong>
# </div>
# <div class="scores">
# <div class="score">115</div>
# </div><div>48-26</div>
# <div class="prevnext">
# <a class="button2 prev" href="/boxscores/199704030NJN.html">Prev Game</a>
# <a class="button2 next" href="/boxscores/199704070CLE.html">Next Game</a>
# </div>
# </div>
# <div class="scorebox_meta">
# <div>April 5, 1997</div><div></div>
# <div><em>Logos <a href="http://www.sportslogos.net/">via Sports Logos.net</a>
#             / <a href="//www.sports-reference.com/blog/2016/06/redesign-team-and-league-logos-courtesy-sportslogos-net/">About logos</a></em></div>
# </div>
# </div>
# <style>
# .fb .scorebox { position: relative; max-width: 640px; }
# .fb .scorebox > div:first-child .scores > div:after { position: absolute; left: 0; content: ':'; width: 100%; }
# .fb .scorebox .scorebox_meta { margin-top: 10px; }
# .fb .scorebox .score { font-size: 1.9em; font-weight: 800; }
# .fb .scorebox .score_pen, .fb .scorebox .score_aggr, .fb .scorebox .score_xg { font-size: 1.28em; font-weight: bold; margin-top: 12px; }
# .fb .scorebox > div:first-child .score_pen:before, .fb .scorebox > div:first-child .score_aggr:before, .fb .scorebox > div:first-child .score_xg:before {
# 	position: absolute;
# 	width: 100%;
# 	left: 0;
# 	margin-top: -11px;
# 	color: #777;
# 	font-size: 13px;
# 	font-weight: bold;
# }
# .fb .scorebox > div:first-child .score_pen:before  { content: 'Penalties'; }
# .fb .scorebox > div:first-child .score_aggr:before { content: 'Aggregate'; }
# .fb .scorebox > div:first-child .score_xg:before { content: 'xG'; }
#
# @media screen and (min-width: 470px) {
# 	.fb .scorebox .prevnext { min-width: 200px; }
# }
#
# @media screen and (min-width: 800px) {
# 	.fb .scorebox                   .scores  { position: absolute; top: 35px; left: 0; }
# 	.fb .scorebox > div:first-child .scores  { left: auto; right: 0; }
#
# 	.fb .scorebox .scores > div       { padding: 0 10px; }
# 	.fb .scorebox > div:first-child .scores > div:after { width: 200%; }
#
# 	.fb .scorebox .score { font-size: 2.7em; }
#
# 	.fb .scorebox .score_pen, .fb .scorebox .score_aggr, .fb .scorebox .score_xg { margin-top: 17px; }
#
# 	.fb .scorebox > div:first-child .score_pen:before, .fb .scorebox > div:first-child .score_aggr:before, .fb .scorebox > div:first-child .score_xg:before { width: 200%; margin-top: -15px; }
#
# 	.fb .scorebox > div { padding: 0 8%; position: relative; }
# 	.fb .scorebox .event { position: absolute; padding: 0; top: 15px; right: -160px; text-align: left; }
# 	.fb .scorebox .event#a { text-align: right; left: -160px; right: auto; }
# 	.fb .scorebox .event > div { margin-bottom: 6px; }
# }
#
# @media screen and (max-width: 1020px) {
# 	.fb .scorebox .event { display: none; }
# }
# </style>
# <!-- fs_btf_3 -->
# <div class="adblock">
# <!-- div#fs_fs_btf_3  -->
# <div align="center" data-freestar-ad="__300x250 __970x90" id="div-gpt-ad-728x90-BTF-3">
# <script data-cfasync="false" type="text/javascript">
#     if (sr_detect_ie || sr_detect_edge || Modernizr.adfree) {
#     }
#     else {
#         console.log('push ad:div-gpt-ad-728x90-BTF-3');
#         freestar.queue.push(function() { googletag.display('div-gpt-ad-728x90-BTF-3'); });
#     }
#     </script>
# </div>
# <!-- /div.#fs_fs_btf_3 -->
# </div>
# <div class="filter">
# <div class="current">
# <a href="/boxscores/199704050CHH.html">Box Score</a>
# </div><div class="">
# <a href="/boxscores/pbp/199704050CHH.html">Play-By-Play</a>
# </div><div class="">
# <a href="/boxscores/shot-chart/199704050CHH.html">Shot Charts</a>
# </div><div class="">
# <a href="/boxscores/plus-minus/199704050CHH.html">Plus/Minus</a>
# </div></div>
# <div class="callout light new_stathead_player_highlight stathead_event">
# <div class="callout_logos">
# <a class="sh-cta-button" href="https://stathead.com/sport/basketball/?&amp;utm_medium=sr_xsite&amp;utm_source=bbr&amp;utm_campaign=2023_03_bnnr_boxes_stathead&amp;utm_content=img_logo&amp;__hstc=180814520.8811cf754d6d43c21af0acc416858cc5.1682445088472.1682445088472.1682445088472.1&amp;__hssc=180814520.1.1682445088472&amp;__hsfp=3688022397" rel="noopener" target="_blank">
# <img alt="Stathead Logo" onerror="this.src='https://cdn.ssref.net/req/202004233/logos/bbr-logo.png'; this.onerror = null;" src="https://cdn.ssref.net/req/202004233/logos/stathead-bbr.svg"/>
# </a>
# <div>POWERED BY</div>
# <a class="sh-cta-button" href="https://stathead.com/sport/basketball/?&amp;utm_medium=sr_xsite&amp;utm_source=bbr&amp;utm_campaign=2023_03_bnnr_boxes_stathead&amp;utm_content=img_logo&amp;__hstc=180814520.8811cf754d6d43c21af0acc416858cc5.1682445088472.1682445088472.1682445088472.1&amp;__hssc=180814520.1.1682445088472&amp;__hsfp=3688022397" rel="noopener" target="_blank">
# <img alt=".com Logo" onerror="this.src='https://cdn.ssref.net/req/202004233/logos/bbr-logo.png'; this.onerror = null;" src="https://cdn.ssref.net/req/202004233/logos/bbr-logo.svg"/>
# </a>
# </div>
# <div class="new_stathead_player_highlight_content">
# <div><b>Looking for something amazing? Uncover the story that stats can tell with Stathead.</b></div>
# <div class="cta">Search through thousands of plays from basketball history using our Event Finder tool.</div>
# <div>
# <a class="button" href="https://stathead.com/sport/basketball/?&amp;utm_medium=sr_xsite&amp;utm_source=bbr&amp;utm_campaign=2023_03_bnnr_boxes_stathead&amp;utm_content=bttn_cta&amp;__hstc=180814520.8811cf754d6d43c21af0acc416858cc5.1682445088472.1682445088472.1682445088472.1&amp;__hssc=180814520.1.1682445088472&amp;__hsfp=3688022397" rel="noopener" target="_blank">Try it &amp; get your first month FREE</a>
# </div>
# </div>
# </div>
# <div class="content_grid">
# <div>
# <div class="table_wrapper" id="all_line_score">
# <div class="section_heading assoc_line_score" id="line_score_sh">
# <span class="section_anchor" data-label="Line Score" id="line_score_link"></span><h2>Line Score</h2> <div class="section_heading_text">
# <ul>
# </ul>
# </div>
# </div><div class="placeholder"></div>
# <!--
#
# <div class="table_container" id="div_line_score">
#
#     <table class="suppress_all stats_table" id="line_score" data-cols-to-freeze="0">
#     <caption>Line Score Table</caption>
#
#
#    <colgroup><col><col><col><col><col><col></colgroup>
#    <thead>
#
#
#       <tr class="over_header">
#          <th aria-label="" data-stat="header_tmp" colspan="6" class=" over_header center" >Scoring</th>
#       </tr>
#
#       <tr>
#          <th aria-label="&nbsp;" data-stat="team" scope="col" class=" poptip center" data-over-header="Scoring" >&nbsp;</th>
#          <th aria-label="1" data-stat="1" scope="col" class=" poptip center" data-over-header="Scoring" >1</th>
#          <th aria-label="2" data-stat="2" scope="col" class=" poptip center" data-over-header="Scoring" >2</th>
#          <th aria-label="3" data-stat="3" scope="col" class=" poptip center" data-over-header="Scoring" >3</th>
#          <th aria-label="4" data-stat="4" scope="col" class=" poptip center" data-over-header="Scoring" >4</th>
#          <th aria-label="T" data-stat="T" scope="col" class=" poptip center" data-over-header="Scoring" >T</th>
#       </tr>
#       </thead>
# <tbody><tr ><th scope="row" class="center " data-stat="team" ><a href='/teams/PHI/1997.html'>PHI</a></th><td class="center " data-stat="1" >34</td><td class="center " data-stat="2" >35</td><td class="center " data-stat="3" >29</td><td class="center " data-stat="4" >15</td><td class="center " data-stat="T" ><strong>113</strong></td></tr>
# <tr ><th scope="row" class="center " data-stat="team" ><a href='/teams/CHH/1997.html'>CHH</a></th><td class="center " data-stat="1" >36</td><td class="center " data-stat="2" >30</td><td class="center " data-stat="3" >25</td><td class="center " data-stat="4" >24</td><td class="center " data-stat="T" ><strong>115</strong></td></tr>
#
# </table>
#
#
# </div>
# -->
# <div class="table_container is_setup" id="div_line_score">
# <table class="suppress_all stats_table" data-cols-to-freeze="0" id="line_score">
# <caption>Line Score Table</caption>
# <colgroup><col/><col/><col/><col/><col/><col/></colgroup>
# <thead>
#
# <tr>
# <th aria-label=" " class="poptip center" data-over-header="Scoring" data-stat="team" scope="col"> </th>
# <th aria-label="1" class="poptip center" data-over-header="Scoring" data-stat="1" scope="col">1</th>
# <th aria-label="2" class="poptip center" data-over-header="Scoring" data-stat="2" scope="col">2</th>
# <th aria-label="3" class="poptip center" data-over-header="Scoring" data-stat="3" scope="col">3</th>
# <th aria-label="4" class="poptip center" data-over-header="Scoring" data-stat="4" scope="col">4</th>
# <th aria-label="T" class="poptip center" data-over-header="Scoring" data-stat="T" scope="col">T</th>
# </tr>
# </thead>
# <tbody><tr><th class="center" data-stat="team" scope="row"><a href="/teams/PHI/1997.html">PHI</a></th><td class="center" data-stat="1">34</td><td class="center" data-stat="2">35</td><td class="center" data-stat="3">29</td><td class="center" data-stat="4">15</td><td class="center" data-stat="T"><strong>113</strong></td></tr>
# <tr><th class="center" data-stat="team" scope="row"><a href="/teams/CHH/1997.html">CHH</a></th><td class="center" data-stat="1">36</td><td class="center" data-stat="2">30</td><td class="center" data-stat="3">25</td><td class="center" data-stat="4">24</td><td class="center" data-stat="T"><strong>115</strong></td></tr>
# </tbody></table>
# </div>
# </div>
# </div><div>
# <div class="table_wrapper" id="all_four_factors">
# <div class="section_heading assoc_four_factors" id="four_factors_sh">
# <span class="section_anchor" data-label="Four Factors" id="four_factors_link"></span><h2>Four Factors</h2> <div class="section_heading_text">
# <ul>
# </ul>
# </div>
# </div><div class="placeholder"></div>
# <!--
#
# <div class="table_container" id="div_four_factors">
#
#     <table class="suppress_all stats_table" id="four_factors" data-cols-to-freeze=",1">
#     <caption>Four Factors Table</caption>
#
#
#    <colgroup><col><col><col><col><col><col><col></colgroup>
#    <thead>
#
#
#       <tr class="over_header">
#          <th aria-label="" data-stat="" colspan="2" class=" over_header center" ></th>
#          <th aria-label="" data-stat="header_tmp" colspan="4" class=" over_header center" >Four Factors</th><th></th>
#       </tr>
#
#       <tr>
#          <th aria-label="&nbsp;" data-stat="team_id" scope="col" class=" poptip sort_default_asc left" data-tip="Team" >&nbsp;</th>
#          <th aria-label="Pace Factor" data-stat="pace" scope="col" class=" poptip right" data-tip="<b>Pace Factor</b>: An estimate of possessions per 48 minutes" >Pace</th>
#          <th aria-label="Effective Field Goal Percentage" data-stat="efg_pct" scope="col" class=" poptip right" data-tip="<strong>Effective Field Goal Percentage</strong><br>This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal." data-over-header="Four Factors" >eFG%</th>
#          <th aria-label="Turnover Percentage" data-stat="tov_pct" scope="col" class=" poptip sort_default_asc right" data-tip="<b>Turnover Percentage</b><br>An estimate of turnovers committed per 100 plays." data-over-header="Four Factors" >TOV%</th>
#          <th aria-label="Offensive Rebound Percentage" data-stat="orb_pct" scope="col" class=" poptip right" data-tip="<b>Offensive Rebound Percentage</b><br>An estimate of the percentage of available offensive rebounds a player grabbed while they were on the floor." data-over-header="Four Factors" >ORB%</th>
#          <th aria-label="FT/FGA" data-stat="ft_rate" scope="col" class=" poptip right" data-tip="Free Throws Per Field Goal Attempt" data-over-header="Four Factors" >FT/FGA</th>
#          <th aria-label="Offensive Rating" data-stat="off_rtg" scope="col" class=" poptip right" data-tip="<b>Offensive Rating</b><br>An estimate of points produced (players) or scored (teams) per 100 possessions" >ORtg</th>
#       </tr>
#       </thead>
# <tbody><tr ><th scope="row" class="left " data-stat="team_id" ><a href="/teams/PHI/1997.html">PHI</a></th><td class="right " data-stat="pace" >95.1</td><td class="right plus" data-stat="efg_pct" >.522</td><td class="right minus" data-stat="tov_pct" >13.6</td><td class="right plus" data-stat="orb_pct" >44.2</td><td class="right plus" data-stat="ft_rate" >.225</td><td class="right " data-stat="off_rtg" >118.8</td></tr>
# <tr ><th scope="row" class="left " data-stat="team_id" ><a href="/teams/CHH/1997.html">CHH</a></th><td class="right " data-stat="pace" >95.1</td><td class="right minus" data-stat="efg_pct" >.485</td><td class="right plus" data-stat="tov_pct" >9.8</td><td class="right minus" data-stat="orb_pct" >43.8</td><td class="right minus" data-stat="ft_rate" >.192</td><td class="right " data-stat="off_rtg" >120.9</td></tr>
#
# </table>
#
#
# </div>
# -->
# <div class="table_container is_setup" id="div_four_factors">
# <table class="suppress_all stats_table" data-cols-to-freeze=",1" id="four_factors">
# <caption>Four Factors Table</caption>
# <colgroup><col/><col/><col/><col/><col/><col/><col/></colgroup>
# <thead>
#
# <tr>
# <th aria-label=" " class="poptip sort_default_asc left" data-stat="team_id" data-tip="Team" scope="col"> </th>
# <th aria-label="Pace Factor" class="poptip right" data-stat="pace" data-tip="&lt;b&gt;Pace Factor&lt;/b&gt;: An estimate of possessions per 48 minutes" scope="col">Pace</th>
# <th aria-label="Effective Field Goal Percentage" class="poptip right" data-over-header="Four Factors" data-stat="efg_pct" data-tip="&lt;strong&gt;Effective Field Goal Percentage&lt;/strong&gt;&lt;br&gt;This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal." scope="col">eFG%</th>
# <th aria-label="Turnover Percentage" class="poptip sort_default_asc right" data-over-header="Four Factors" data-stat="tov_pct" data-tip="&lt;b&gt;Turnover Percentage&lt;/b&gt;&lt;br&gt;An estimate of turnovers committed per 100 plays." scope="col">TOV%</th>
# <th aria-label="Offensive Rebound Percentage" class="poptip right" data-over-header="Four Factors" data-stat="orb_pct" data-tip="&lt;b&gt;Offensive Rebound Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of available offensive rebounds a player grabbed while they were on the floor." scope="col">ORB%</th>
# <th aria-label="FT/FGA" class="poptip right" data-over-header="Four Factors" data-stat="ft_rate" data-tip="Free Throws Per Field Goal Attempt" scope="col">FT/FGA</th>
# <th aria-label="Offensive Rating" class="poptip right" data-stat="off_rtg" data-tip="&lt;b&gt;Offensive Rating&lt;/b&gt;&lt;br&gt;An estimate of points produced (players) or scored (teams) per 100 possessions" scope="col">ORtg</th>
# </tr>
# </thead>
# <tbody><tr><th class="left" data-stat="team_id" scope="row"><a href="/teams/PHI/1997.html">PHI</a></th><td class="right" data-stat="pace">95.1</td><td class="right plus" data-stat="efg_pct">.522</td><td class="right minus" data-stat="tov_pct">13.6</td><td class="right plus" data-stat="orb_pct">44.2</td><td class="right plus" data-stat="ft_rate">.225</td><td class="right" data-stat="off_rtg">118.8</td></tr>
# <tr><th class="left" data-stat="team_id" scope="row"><a href="/teams/CHH/1997.html">CHH</a></th><td class="right" data-stat="pace">95.1</td><td class="right minus" data-stat="efg_pct">.485</td><td class="right plus" data-stat="tov_pct">9.8</td><td class="right minus" data-stat="orb_pct">43.8</td><td class="right minus" data-stat="ft_rate">.192</td><td class="right" data-stat="off_rtg">120.9</td></tr>
# </tbody></table>
# </div>
# </div>
# </div>
# </div>
# <div class="filter switcher"><div class="current" onclick="sr_st_construct_stats_table_features('box-PHI-game-basic', 0); sr_st_construct_stats_table_features('box-CHH-game-basic', 0);"><a class="sr_preset" data-hide=".box-PHI,.box-CHH" data-show=".box-PHI-game,.box-CHH-game" href="javascript:void(0)" style="visibility: visible;">Game</a></div> <div class="" onclick="sr_st_construct_stats_table_features('box-PHI-q1-basic', 0); sr_st_construct_stats_table_features('box-CHH-q1-basic', 0);"><a class="sr_preset" data-hide=".box-PHI,.box-CHH" data-show=".box-PHI-q1,.box-CHH-q1" href="javascript:void(0)" style="visibility: visible;">Q1</a></div> <div class="" onclick="sr_st_construct_stats_table_features('box-PHI-q2-basic', 0); sr_st_construct_stats_table_features('box-CHH-q2-basic', 0);"><a class="sr_preset" data-hide=".box-PHI,.box-CHH" data-show=".box-PHI-q2,.box-CHH-q2" href="javascript:void(0)" style="visibility: visible;">Q2</a></div> <div class="" onclick="sr_st_construct_stats_table_features('box-PHI-h1-basic', 0); sr_st_construct_stats_table_features('box-CHH-h1-basic', 0);"><a class="sr_preset" data-hide=".box-PHI,.box-CHH" data-show=".box-PHI-h1,.box-CHH-h1" href="javascript:void(0)" style="visibility: visible;">H1</a></div> <div class="" onclick="sr_st_construct_stats_table_features('box-PHI-q3-basic', 0); sr_st_construct_stats_table_features('box-CHH-q3-basic', 0);"><a class="sr_preset" data-hide=".box-PHI,.box-CHH" data-show=".box-PHI-q3,.box-CHH-q3" href="javascript:void(0)" style="visibility: visible;">Q3</a></div> <div class="" onclick="sr_st_construct_stats_table_features('box-PHI-q4-basic', 0); sr_st_construct_stats_table_features('box-CHH-q4-basic', 0);"><a class="sr_preset" data-hide=".box-PHI,.box-CHH" data-show=".box-PHI-q4,.box-CHH-q4" href="javascript:void(0)" style="visibility: visible;">Q4</a></div> <div class="" onclick="sr_st_construct_stats_table_features('box-PHI-h2-basic', 0); sr_st_construct_stats_table_features('box-CHH-h2-basic', 0);"><a class="sr_preset" data-hide=".box-PHI,.box-CHH" data-show=".box-PHI-h2,.box-CHH-h2" href="javascript:void(0)" style="visibility: visible;">H2</a></div></div><div class="section_wrapper box-PHI box-PHI-game" id="all_box-PHI-game-basic"> <div class="section_content is_setup" id="div_box-PHI-game-basic">
# <div class="table_wrapper" id="all_box-PHI-game-basic">
# <div class="section_heading assoc_box-PHI-game-basic has_controls" id="box-PHI-game-basic_sh">
# <span class="section_anchor" data-label="Philadelphia 76ers Basic and Advanced Stats" id="box-PHI-game-basic_link"></span><h2>Philadelphia 76ers Basic and Advanced Stats</h2> <div class="section_heading_text">
# <ul>
# <li class="hasmore"><span>Share &amp; Export</span><div><ul><li><button class="tooltip" id="share_on_box-PHI-game-basic" tip="Use a customizable report creator that can&lt;br&gt;output HTML, CSV, or a shareable link." type="button">Modify, Export &amp; Share Table</button></li><li><button class="tooltip" tip="Convert the table below to comma-separated values&lt;br&gt;suitable for use with Excel" type="button">Get as Excel Workbook</button><a id="dlink" style="display: none;"></a></li><li><button class="tooltip" tip="Get a link directly to this table on this page" type="button">Get table as CSV (for Excel)</button></li><li><button class="tooltip" href="#box-PHI-game-basic" id="a_box-PHI-game-basic" name="box-PHI-game-basic" tip="" type="button">Get Link to Table</button></li><li><button class="tooltip" tip="" type="button">About Sharing Tools</button></li><li><button class="tooltip" tip="" type="button"><a href="https://www.youtube.com/watch?v=MWapXbaWs_U&amp;feature=youtu.be" target="_blank">Video: SR Sharing Tools &amp; How-to</a></button></li><li><button class="tooltip" tip="" type="button"><a href="https://www.youtube.com/watch?v=JkDLV0roT14&amp;feature=youtu.be" target="_blank">Video: Stats Table Tips &amp; Tricks</a></button></li><li><button class="tooltip" tip="" type="button"><a href="https://www.sports-reference.com/data_use.html" target="_blank">Data Usage Terms</a></button></li></ul></div></li><li><button class="tooltip" tip="Show a glossary for each term in the table below&lt;br&gt;or hold your mouse over the header" type="button">Glossary</button></li></ul>
# </div>
# </div>
# <div class="table_container" id="div_box-PHI-game-basic">
# <table class="sortable stats_table now_sortable" data-cols-to-freeze=",1" id="box-PHI-game-basic">
# <caption>Philadelphia 76ers Basic and Advanced Stats Table</caption>
# <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup>
# <thead>
#
# <tr>
# <th aria-label="Starters" class="poptip sort_default_asc center" data-stat="player" scope="col">Starters</th>
# <th aria-label="Minutes Played" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="mp" data-tip="Minutes Played" scope="col">MP</th>
# <th aria-label="Field Goals" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fg" data-tip="Field Goals" scope="col">FG</th>
# <th aria-label="FGA" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fga" data-tip="Field Goal Attempts" scope="col">FGA</th>
# <th aria-label="Field Goal Percentage" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fg_pct" data-tip="Field Goal Percentage" scope="col">FG%</th>
# <th aria-label="3-Point Field Goals" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fg3" data-tip="3-Point Field Goals" scope="col">3P</th>
# <th aria-label="3-Point Field Goal Attempts" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fg3a" data-tip="3-Point Field Goal Attempts" scope="col">3PA</th>
# <th aria-label="3-Point Field Goal Percentage" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fg3_pct" data-tip="3-Point Field Goal Percentage" scope="col">3P%</th>
# <th aria-label="Free Throws" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="ft" data-tip="Free Throws" scope="col">FT</th>
# <th aria-label="Free Throw Attempts" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fta" data-tip="Free Throw Attempts" scope="col">FTA</th>
# <th aria-label="Free Throw Percentage" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="ft_pct" data-tip="Free Throw Percentage" scope="col">FT%</th>
# <th aria-label="Offensive Rebounds" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="orb" data-tip="Offensive Rebounds" scope="col">ORB</th>
# <th aria-label="Defensive Rebounds" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="drb" data-tip="Defensive Rebounds" scope="col">DRB</th>
# <th aria-label="Total Rebounds" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="trb" data-tip="Total Rebounds" scope="col">TRB</th>
# <th aria-label="Assists" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="ast" data-tip="Assists" scope="col">AST</th>
# <th aria-label="Steals" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="stl" data-tip="Steals" scope="col">STL</th>
# <th aria-label="Blocks" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="blk" data-tip="Blocks" scope="col">BLK</th>
# <th aria-label="Turnovers" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="tov" data-tip="Turnovers" scope="col">TOV</th>
# <th aria-label="Personal Fouls" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="pf" data-tip="Personal Fouls" scope="col">PF</th>
# <th aria-label="Points" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="pts" data-tip="Points" scope="col">PTS</th>
# <th aria-label="Plus/Minus" class="poptip right" data-over-header="Basic Box Score Stats" data-stat="plus_minus" data-tip="Plus/Minus" scope="col">+/-</th>
# </tr>
# </thead>
# <tbody><tr data-row="0"><th class="left" csk="Stackhouse,Jerry" data-append-csv="stackje01" data-stat="player" scope="row"><a href="/players/s/stackje01.html">Jerry Stackhouse</a></th><td class="right" csk="2880" data-stat="mp">48:00</td><td class="right" data-stat="fg">14</td><td class="right" data-stat="fga">24</td><td class="right" data-stat="fg_pct">.583</td><td class="right" data-stat="fg3">4</td><td class="right" data-stat="fg3a">7</td><td class="right" data-stat="fg3_pct">.571</td><td class="right" data-stat="ft">7</td><td class="right" data-stat="fta">9</td><td class="right" data-stat="ft_pct">.778</td><td class="right" data-stat="orb">1</td><td class="right" data-stat="drb">1</td><td class="right" data-stat="trb">2</td><td class="right" data-stat="ast">5</td><td class="right" data-stat="stl">1</td><td class="right iz" data-stat="blk">0</td><td class="right" data-stat="tov">4</td><td class="right" data-stat="pf">5</td><td class="right" data-stat="pts">39</td><td class="right" data-stat="plus_minus">-2</td></tr>
# <tr data-row="1"><th class="left" csk="Iverson,Allen" data-append-csv="iversal01" data-stat="player" scope="row"><a href="/players/i/iversal01.html">Allen Iverson</a></th><td class="right" csk="2880" data-stat="mp">48:00</td><td class="right" data-stat="fg">12</td><td class="right" data-stat="fga">28</td><td class="right" data-stat="fg_pct">.429</td><td class="right" data-stat="fg3">2</td><td class="right" data-stat="fg3a">3</td><td class="right" data-stat="fg3_pct">.667</td><td class="right" data-stat="ft">6</td><td class="right" data-stat="fta">7</td><td class="right" data-stat="ft_pct">.857</td><td class="right" data-stat="orb">4</td><td class="right" data-stat="drb">6</td><td class="right" data-stat="trb">10</td><td class="right" data-stat="ast">7</td><td class="right" data-stat="stl">3</td><td class="right iz" data-stat="blk">0</td><td class="right" data-stat="tov">5</td><td class="right" data-stat="pf">3</td><td class="right" data-stat="pts">32</td><td class="right" data-stat="plus_minus">-2</td></tr>
# <tr data-row="2"><th class="left" csk="Weatherspoon,Clarence" data-append-csv="weathcl01" data-stat="player" scope="row"><a href="/players/w/weathcl01.html">Clarence Weatherspoon</a></th><td class="right" csk="2561" data-stat="mp">42:41</td><td class="right" data-stat="fg">7</td><td class="right" data-stat="fga">13</td><td class="right" data-stat="fg_pct">.538</td><td class="right iz" data-stat="fg3">0</td><td class="right iz" data-stat="fg3a">0</td><td class="right iz" data-stat="fg3_pct"></td><td class="right" data-stat="ft">4</td><td class="right" data-stat="fta">6</td><td class="right" data-stat="ft_pct">.667</td><td class="right" data-stat="orb">2</td><td class="right" data-stat="drb">7</td><td class="right" data-stat="trb">9</td><td class="right" data-stat="ast">2</td><td class="right" data-stat="stl">1</td><td class="right" data-stat="blk">4</td><td class="right" data-stat="tov">1</td><td class="right" data-stat="pf">1</td><td class="right" data-stat="pts">18</td><td class="right" data-stat="plus_minus">+2</td></tr>
# <tr data-row="3"><th class="left" csk="Davis,Mark" data-append-csv="davisma02" data-stat="player" scope="row"><a href="/players/d/davisma02.html">Mark Davis</a></th><td class="right" csk="2471" data-stat="mp">41:11</td><td class="right" data-stat="fg">4</td><td class="right" data-stat="fga">9</td><td class="right" data-stat="fg_pct">.444</td><td class="right" data-stat="fg3">1</td><td class="right" data-stat="fg3a">3</td><td class="right" data-stat="fg3_pct">.333</td><td class="right iz" data-stat="ft">0</td><td class="right iz" data-stat="fta">0</td><td class="right iz" data-stat="ft_pct"></td><td class="right" data-stat="orb">1</td><td class="right" data-stat="drb">5</td><td class="right" data-stat="trb">6</td><td class="right" data-stat="ast">4</td><td class="right" data-stat="stl">1</td><td class="right iz" data-stat="blk">0</td><td class="right" data-stat="tov">3</td><td class="right" data-stat="pf">4</td><td class="right" data-stat="pts">9</td><td class="right" data-stat="plus_minus">+1</td></tr>
# <tr data-row="4"><th class="left" csk="Williams,Scott" data-append-csv="willisc01" data-stat="player" scope="row"><a href="/players/w/willisc01.html">Scott Williams</a></th><td class="right" csk="1403" data-stat="mp">23:23</td><td class="right" data-stat="fg">4</td><td class="right" data-stat="fga">6</td><td class="right" data-stat="fg_pct">.667</td><td class="right iz" data-stat="fg3">0</td><td class="right iz" data-stat="fg3a">0</td><td class="right iz" data-stat="fg3_pct"></td><td class="right iz" data-stat="ft">0</td><td class="right iz" data-stat="fta">0</td><td class="right iz" data-stat="ft_pct"></td><td class="right" data-stat="orb">3</td><td class="right" data-stat="drb">2</td><td class="right" data-stat="trb">5</td><td class="right" data-stat="ast">2</td><td class="right" data-stat="stl">1</td><td class="right iz" data-stat="blk">0</td><td class="right" data-stat="tov">1</td><td class="right" data-stat="pf">5</td><td class="right" data-stat="pts">8</td><td class="right" data-stat="plus_minus">+7</td></tr>
# <tr class="thead" data-row="5">
# <th aria-label="Reserves" class="sort_default_asc center" data-stat="player">Reserves</th>
# <th aria-label="Minutes Played" class="center" data-stat="mp" data-tip="Minutes Played">MP</th>
# <th aria-label="Field Goals" class="center" data-stat="fg" data-tip="Field Goals">FG</th>
# <th aria-label="FGA" class="center" data-stat="fga" data-tip="Field Goal Attempts">FGA</th>
# <th aria-label="Field Goal Percentage" class="center" data-stat="fg_pct" data-tip="Field Goal Percentage">FG%</th>
# <th aria-label="3-Point Field Goals" class="center" data-stat="fg3" data-tip="3-Point Field Goals">3P</th>
# <th aria-label="3-Point Field Goal Attempts" class="center" data-stat="fg3a" data-tip="3-Point Field Goal Attempts">3PA</th>
# <th aria-label="3-Point Field Goal Percentage" class="center" data-stat="fg3_pct" data-tip="3-Point Field Goal Percentage">3P%</th>
# <th aria-label="Free Throws" class="center" data-stat="ft" data-tip="Free Throws">FT</th>
# <th aria-label="Free Throw Attempts" class="center" data-stat="fta" data-tip="Free Throw Attempts">FTA</th>
# <th aria-label="Free Throw Percentage" class="center" data-stat="ft_pct" data-tip="Free Throw Percentage">FT%</th>
# <th aria-label="Offensive Rebounds" class="center" data-stat="orb" data-tip="Offensive Rebounds">ORB</th>
# <th aria-label="Defensive Rebounds" class="center" data-stat="drb" data-tip="Defensive Rebounds">DRB</th>
# <th aria-label="Total Rebounds" class="center" data-stat="trb" data-tip="Total Rebounds">TRB</th>
# <th aria-label="Assists" class="center" data-stat="ast" data-tip="Assists">AST</th>
# <th aria-label="Steals" class="center" data-stat="stl" data-tip="Steals">STL</th>
# <th aria-label="Blocks" class="center" data-stat="blk" data-tip="Blocks">BLK</th>
# <th aria-label="Turnovers" class="center" data-stat="tov" data-tip="Turnovers">TOV</th>
# <th aria-label="Personal Fouls" class="center" data-stat="pf" data-tip="Personal Fouls">PF</th>
# <th aria-label="Points" class="center" data-stat="pts" data-tip="Points">PTS</th>
# <th aria-label="Plus/Minus" class="right" data-stat="plus_minus" data-tip="Plus/Minus">+/-</th>
# </tr>
# <tr data-row="6"><th class="left" csk="Caldwell,Adrian" data-append-csv="caldwad01" data-stat="player" scope="row"><a href="/players/c/caldwad01.html">Adrian Caldwell</a></th><td class="right" csk="1001" data-stat="mp">16:41</td><td class="right" data-stat="fg">2</td><td class="right" data-stat="fga">3</td><td class="right" data-stat="fg_pct">.667</td><td class="right iz" data-stat="fg3">0</td><td class="right iz" data-stat="fg3a">0</td><td class="right iz" data-stat="fg3_pct"></td><td class="right" data-stat="ft">1</td><td class="right" data-stat="fta">4</td><td class="right" data-stat="ft_pct">.250</td><td class="right" data-stat="orb">3</td><td class="right" data-stat="drb">2</td><td class="right" data-stat="trb">5</td><td class="right" data-stat="ast">1</td><td class="right iz" data-stat="stl">0</td><td class="right iz" data-stat="blk">0</td><td class="right" data-stat="tov">2</td><td class="right" data-stat="pf">3</td><td class="right" data-stat="pts">5</td><td class="right" data-stat="plus_minus">-5</td></tr>
# <tr data-row="7"><th class="left" csk="Hendrickson,Mark" data-append-csv="hendrma01" data-stat="player" scope="row"><a href="/players/h/hendrma01.html">Mark Hendrickson</a></th><td class="right" csk="714" data-stat="mp">11:54</td><td class="right iz" data-stat="fg">0</td><td class="right" data-stat="fga">6</td><td class="right iz" data-stat="fg_pct">.000</td><td class="right iz" data-stat="fg3">0</td><td class="right" data-stat="fg3a">1</td><td class="right iz" data-stat="fg3_pct">.000</td><td class="right" data-stat="ft">2</td><td class="right" data-stat="fta">2</td><td class="right" data-stat="ft_pct">1.000</td><td class="right" data-stat="orb">4</td><td class="right" data-stat="drb">3</td><td class="right" data-stat="trb">7</td><td class="right iz" data-stat="ast">0</td><td class="right iz" data-stat="stl">0</td><td class="right iz" data-stat="blk">0</td><td class="right iz" data-stat="tov">0</td><td class="right" data-stat="pf">1</td><td class="right" data-stat="pts">2</td><td class="right" data-stat="plus_minus">-9</td></tr>
# <tr data-row="8"><th class="left" csk="Bradtke,Mark" data-append-csv="bradtma01" data-stat="player" scope="row"><a href="/players/b/bradtma01.html">Mark Bradtke</a></th><td class="right" csk="420" data-stat="mp">7:00</td><td class="right iz" data-stat="fg">0</td><td class="right iz" data-stat="fga">0</td><td class="right iz" data-stat="fg_pct"></td><td class="right iz" data-stat="fg3">0</td><td class="right iz" data-stat="fg3a">0</td><td class="right iz" data-stat="fg3_pct"></td><td class="right iz" data-stat="ft">0</td><td class="right iz" data-stat="fta">0</td><td class="right iz" data-stat="ft_pct"></td><td class="right iz" data-stat="orb">0</td><td class="right" data-stat="drb">1</td><td class="right" data-stat="trb">1</td><td class="right" data-stat="ast">1</td><td class="right iz" data-stat="stl">0</td><td class="right iz" data-stat="blk">0</td><td class="right iz" data-stat="tov">0</td><td class="right" data-stat="pf">1</td><td class="right iz" data-stat="pts">0</td><td class="right" data-stat="plus_minus">-2</td></tr>
# <tr data-row="9"><th class="left" csk="Cage,Michael" data-append-csv="cagemi01" data-stat="player" scope="row"><a href="/players/c/cagemi01.html">Michael Cage</a></th><td class="right" csk="46" data-stat="mp">0:46</td><td class="right iz" data-stat="fg">0</td><td class="right iz" data-stat="fga">0</td><td class="right iz" data-stat="fg_pct"></td><td class="right iz" data-stat="fg3">0</td><td class="right iz" data-stat="fg3a">0</td><td class="right iz" data-stat="fg3_pct"></td><td class="right iz" data-stat="ft">0</td><td class="right iz" data-stat="fta">0</td><td class="right iz" data-stat="ft_pct"></td><td class="right iz" data-stat="orb">0</td><td class="right iz" data-stat="drb">0</td><td class="right iz" data-stat="trb">0</td><td class="right iz" data-stat="ast">0</td><td class="right iz" data-stat="stl">0</td><td class="right iz" data-stat="blk">0</td><td class="right iz" data-stat="tov">0</td><td class="right iz" data-stat="pf">0</td><td class="right iz" data-stat="pts">0</td><td class="right iz" data-stat="plus_minus">0</td></tr>
# <tr data-row="10"><th class="left" csk="King,Frankie" data-append-csv="kingfr01" data-stat="player" scope="row"><a href="/players/k/kingfr01.html">Frankie King</a></th><td class="right" csk="24" data-stat="mp">0:24</td><td class="right iz" data-stat="fg">0</td><td class="right iz" data-stat="fga">0</td><td class="right iz" data-stat="fg_pct"></td><td class="right iz" data-stat="fg3">0</td><td class="right iz" data-stat="fg3a">0</td><td class="right iz" data-stat="fg3_pct"></td><td class="right iz" data-stat="ft">0</td><td class="right iz" data-stat="fta">0</td><td class="right iz" data-stat="ft_pct"></td><td class="right" data-stat="orb">1</td><td class="right iz" data-stat="drb">0</td><td class="right" data-stat="trb">1</td><td class="right iz" data-stat="ast">0</td><td class="right iz" data-stat="stl">0</td><td class="right iz" data-stat="blk">0</td><td class="right iz" data-stat="tov">0</td><td class="right iz" data-stat="pf">0</td><td class="right iz" data-stat="pts">0</td><td class="right iz" data-stat="plus_minus">0</td></tr>
# <tr data-row="11"><th class="left" csk="Coleman,Derrick" data-append-csv="colemde01" data-stat="player" scope="row"><a href="/players/c/colemde01.html">Derrick Coleman</a></th><td class="center" colspan="20" data-stat="reason">Not With Team</td></tr>
# <tr data-row="12"><th class="left" csk="Overton,Doug" data-append-csv="overtdo01" data-stat="player" scope="row"><a href="/players/o/overtdo01.html">Doug Overton</a></th><td class="center" colspan="20" data-stat="reason">Not With Team</td></tr>
# </tbody><tfoot><tr data-row="13"><th class="left" data-stat="player" scope="row">Team Totals</th><td class="right" data-stat="mp">240</td><td class="right" data-stat="fg">43</td><td class="right" data-stat="fga">89</td><td class="right" data-stat="fg_pct">.483</td><td class="right" data-stat="fg3">7</td><td class="right" data-stat="fg3a">14</td><td class="right" data-stat="fg3_pct">.500</td><td class="right" data-stat="ft">20</td><td class="right" data-stat="fta">28</td><td class="right" data-stat="ft_pct">.714</td><td class="right" data-stat="orb">19</td><td class="right" data-stat="drb">27</td><td class="right" data-stat="trb">46</td><td class="right" data-stat="ast">22</td><td class="right" data-stat="stl">7</td><td class="right" data-stat="blk">4</td><td class="right" data-stat="tov">16</td><td class="right" data-stat="pf">23</td><td class="right" data-stat="pts">113</td><td class="right iz" data-stat="plus_minus"></td></tr>
# </tfoot>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="section_wrapper box-PHI box-PHI-q1 toggleable" id="all_box-PHI-q1-basic"> <div class="section_content" id="div_box-PHI-q1-basic">
# <div class="table_wrapper" id="all_box-PHI-q1-basic">
# <div class="section_heading assoc_box-PHI-q1-basic" id="box-PHI-q1-basic_sh">
# <span class="section_anchor" data-label="Philadelphia 76ers (Q1)" data-no-inpage="1" id="box-PHI-q1-basic_link"></span><h2>Philadelphia 76ers (Q1)</h2> <div class="section_heading_text">
# <ul>
# </ul>
# </div>
# </div>
# <div class="table_container" id="div_box-PHI-q1-basic">
# <table class="sortable stats_table" data-cols-to-freeze=",1" id="box-PHI-q1-basic">
# <caption>Philadelphia 76ers (Q1) Table</caption>
# <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup>
# <thead>
#
# <tr>
# <th aria-label="Starters" class="poptip sort_default_asc center" data-stat="player" scope="col">Starters</th>
# <th aria-label="Minutes Played" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="mp" data-tip="Minutes Played" scope="col">MP</th>
# <th aria-label="Field Goals" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fg" data-tip="Field Goals" scope="col">FG</th>
# <th aria-label="FGA" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fga" data-tip="Field Goal Attempts" scope="col">FGA</th>
# <th aria-label="Field Goal Percentage" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fg_pct" data-tip="Field Goal Percentage" scope="col">FG%</th>
# <th aria-label="3-Point Field Goals" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fg3" data-tip="3-Point Field Goals" scope="col">3P</th>
# <th aria-label="3-Point Field Goal Attempts" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fg3a" data-tip="3-Point Field Goal Attempts" scope="col">3PA</th>
# <th aria-label="3-Point Field Goal Percentage" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fg3_pct" data-tip="3-Point Field Goal Percentage" scope="col">3P%</th>
# <th aria-label="Free Throws" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="ft" data-tip="Free Throws" scope="col">FT</th>
# <th aria-label="Free Throw Attempts" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="fta" data-tip="Free Throw Attempts" scope="col">FTA</th>
# <th aria-label="Free Throw Percentage" class="poptip center" data-over-header="Basic Box Score Stats" data-stat="ft_pct" data-tip="Free Throw Percentage" scope="col">FT%</th>
# ...
# <tr data-row="2"><th class="left" csk="Bogues,Muggsy" data-append-csv="boguemu01" data-stat="player" scope="row"><a href="/players/b/boguemu01.html">Muggsy Bogues</a></th><td class="right" csk="1974" data-stat="mp">32:54</td><td class="right" data-stat="ts_pct">.550</td><td class="right" data-stat="efg_pct">.550</td><td class="right" data-stat="fg3a_per_fga_pct">.300</td><td class="right iz" data-stat="fta_per_fga_pct">.000</td><td class="right iz" data-stat="orb_pct">0.0</td><td class="right" data-stat="drb_pct">6.8</td><td class="right" data-stat="trb_pct">3.2</td><td class="right" data-stat="ast_pct">30.8</td><td class="right" data-stat="stl_pct">1.5</td><td class="right iz" data-stat="blk_pct">0.0</td><td class="right" data-stat="tov_pct">9.1</td><td class="right" data-stat="usg_pct">13.1</td><td class="right" data-stat="off_rtg">132</td><td class="right" data-stat="def_rtg">122</td><td class="right poptip" data-stat="bpm" data-tip="OBPM: 0.8&lt;br&gt; DBPM: -2.2&lt;br&gt; VORP: 0.4&lt;br&gt; &lt;em&gt;&lt;small&gt;VORP is prorated to 82 games&lt;/small&gt;&lt;/em&gt; ">-1.4</td></tr>
# <tr data-row="3"><th class="left" csk="Pierce,Ricky" data-append-csv="piercri01" data-stat="player" scope="row"><a href="/players/p/piercri01.html">Ricky Pierce</a></th><td class="right" csk="1945" data-stat="mp">32:25</td><td class="right" data-stat="ts_pct">.474</td><td class="right" data-stat="efg_pct">.385</td><td class="right" data-stat="fg3a_per_fga_pct">.308</td><td class="right" data-stat="fta_per_fga_pct">.308</td><td class="right" data-stat="orb_pct">6.3</td><td class="right" data-stat="drb_pct">7.0</td><td class="right" data-stat="trb_pct">6.6</td><td class="right" data-stat="ast_pct">20.0</td><td class="right" data-stat="stl_pct">3.2</td><td class="right iz" data-stat="blk_pct">0.0</td><td class="right" data-stat="tov_pct">16.9</td><td class="right" data-stat="usg_pct">21.8</td><td class="right" data-stat="off_rtg">105</td><td class="right" data-stat="def_rtg">119</td><td class="right poptip" data-stat="bpm" data-tip="OBPM: -0.5&lt;br&gt; DBPM: -2.0&lt;br&gt; VORP: -0.4&lt;br&gt; &lt;em&gt;&lt;small&gt;VORP is prorated to 82 games&lt;/small&gt;&lt;/em&gt; ">-2.5</td></tr>
# <tr data-row="4"><th class="left" csk="Chambers,Tom" data-append-csv="chambto01" data-stat="player" scope="row"><a href="/players/c/chambto01.html">Tom Chambers</a></th><td class="right" csk="610" data-stat="mp">10:10</td><td class="right" data-stat="ts_pct">.200</td><td class="right" data-stat="efg_pct">.200</td><td class="right iz" data-stat="fg3a_per_fga_pct">.000</td><td class="right iz" data-stat="fta_per_fga_pct">.000</td><td class="right iz" data-stat="orb_pct">0.0</td><td class="right" data-stat="drb_pct">11.2</td><td class="right" data-stat="trb_pct">5.3</td><td class="right iz" data-stat="ast_pct">0.0</td><td class="right iz" data-stat="stl_pct">0.0</td><td class="right iz" data-stat="blk_pct">0.0</td><td class="right iz" data-stat="tov_pct">0.0</td><td class="right" data-stat="usg_pct">19.7</td><td class="right" data-stat="off_rtg">57</td><td class="right" data-stat="def_rtg">124</td><td class="right poptip" data-stat="bpm" data-tip="OBPM: -13.1&lt;br&gt; DBPM: -8.0&lt;br&gt; VORP: -4.1&lt;br&gt; &lt;em&gt;&lt;small&gt;VORP is prorated to 82 games&lt;/small&gt;&lt;/em&gt; ">-21.2</td></tr>
# <tr class="thead" data-row="5">
# <th aria-label="Reserves" class="sort_default_asc center" data-stat="player">Reserves</th>
# <th aria-label="Minutes Played" class="center" data-stat="mp" data-tip="Minutes Played">MP</th>
# <th aria-label="True Shooting Percentage" class="center" data-stat="ts_pct" data-tip="&lt;strong&gt;True Shooting Percentage&lt;/strong&gt;&lt;br&gt;A measure of shooting efficiency that takes into account 2-point field goals, 3-point field goals, and free throws.">TS%</th>
# <th aria-label="Effective Field Goal Percentage" class="center" data-stat="efg_pct" data-tip="&lt;strong&gt;Effective Field Goal Percentage&lt;/strong&gt;&lt;br&gt;This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal.">eFG%</th>
# <th aria-label="3-Point Attempt Rate" class="center" data-stat="fg3a_per_fga_pct" data-tip="&lt;strong&gt;3-Point Attempt Rate&lt;/strong&gt;&lt;br&gt;Percentage of FG Attempts from 3-Point Range">3PAr</th>
# <th aria-label="Free Throw Attempt Rate" class="center" data-stat="fta_per_fga_pct" data-tip="&lt;strong&gt;Free Throw Attempt Rate&lt;/strong&gt;&lt;br&gt;Number of FT Attempts Per FG Attempt">FTr</th>
# <th aria-label="Offensive Rebound Percentage" class="center" data-stat="orb_pct" data-tip="&lt;b&gt;Offensive Rebound Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of available offensive rebounds a player grabbed while they were on the floor.">ORB%</th>
# <th aria-label="Defensive Rebound Percentage" class="center" data-stat="drb_pct" data-tip="&lt;b&gt;Defensive Rebound Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of available defensive rebounds a player grabbed while they were on the floor.">DRB%</th>
# <th aria-label="Total Rebound Percentage" class="center" data-stat="trb_pct" data-tip="&lt;b&gt;Total Rebound Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of available rebounds a player grabbed while they were on the floor.">TRB%</th>
# <th aria-label="Assist Percentage" class="center" data-stat="ast_pct" data-tip="&lt;b&gt;Assist Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of teammate field goals a player assisted while they were on the floor.">AST%</th>
# <th aria-label="Steal Percentage" class="center" data-stat="stl_pct" data-tip="&lt;b&gt;Steal Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of opponent possessions that end with a steal by the player while they were on the floor.">STL%</th>
# <th aria-label="Block Percentage" class="center" data-stat="blk_pct" data-tip="&lt;b&gt;Block Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of opponent two-point field goal attempts blocked by the player while they were on the floor.">BLK%</th>
# <th aria-label="Turnover Percentage" class="sort_default_asc center" data-stat="tov_pct" data-tip="&lt;b&gt;Turnover Percentage&lt;/b&gt;&lt;br&gt;An estimate of turnovers committed per 100 plays.">TOV%</th>
# <th aria-label="Usage Percentage" class="center" data-stat="usg_pct" data-tip="&lt;b&gt;Usage Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of team plays used by a player while they were on the floor.">USG%</th>
# <th aria-label="Offensive Rating" class="center" data-stat="off_rtg" data-tip="&lt;b&gt;Offensive Rating&lt;/b&gt;&lt;br&gt;An estimate of points produced (players) or scored (teams) per 100 possessions">ORtg</th>
# <th aria-label="Defensive Rating" class="sort_default_asc center" data-stat="def_rtg" data-tip="&lt;b&gt;Defensive Rating&lt;/b&gt;&lt;br&gt;An estimate of points allowed per 100 possessions">DRtg</th>
# <th aria-label="BPM" class="right" data-stat="bpm" data-tip="&lt;b&gt;Box Plus/Minus&lt;/b&gt;&lt;br&gt;A box score estimate of the points per 100 possessions a player contributed above a league-average player, translated to an average team.">BPM</th>
# </tr>
# <tr data-row="6"><th class="left" csk="Geiger,Matt" data-append-csv="geigema01" data-stat="player" scope="row"><a href="/players/g/geigema01.html">Matt Geiger</a></th><td class="right" csk="2032" data-stat="mp">33:52</td><td class="right" data-stat="ts_pct">.550</td><td class="right" data-stat="efg_pct">.545</td><td class="right iz" data-stat="fg3a_per_fga_pct">.000</td><td class="right" data-stat="fta_per_fga_pct">.545</td><td class="right" data-stat="orb_pct">23.5</td><td class="right" data-stat="drb_pct">16.4</td><td class="right" data-stat="trb_pct">20.2</td><td class="right" data-stat="ast_pct">7.7</td><td class="right" data-stat="stl_pct">1.5</td><td class="right" data-stat="blk_pct">1.9</td><td class="right iz" data-stat="tov_pct">0.0</td><td class="right" data-stat="usg_pct">15.8</td><td class="right" data-stat="off_rtg">142</td><td class="right" data-stat="def_rtg">117</td><td class="right poptip" data-stat="bpm" data-tip="OBPM: 4.9&lt;br&gt; DBPM: -3.2&lt;br&gt; VORP: 2.6&lt;br&gt; &lt;em&gt;&lt;small&gt;VORP is prorated to 82 games&lt;/small&gt;&lt;/em&gt; ">1.7</td></tr>
# <tr data-row="7"><th class="left" csk="Royal,Donald" data-append-csv="royaldo01" data-stat="player" scope="row"><a href="/players/r/royaldo01.html">Donald Royal</a></th><td class="right" csk="952" data-stat="mp">15:52</td><td class="right" data-stat="ts_pct">.250</td><td class="right" data-stat="efg_pct">.250</td><td class="right iz" data-stat="fg3a_per_fga_pct">.000</td><td class="right iz" data-stat="fta_per_fga_pct">.000</td><td class="right" data-stat="orb_pct">6.3</td><td class="right" data-stat="drb_pct">14.0</td><td class="right" data-stat="trb_pct">9.9</td><td class="right iz" data-stat="ast_pct">0.0</td><td class="right iz" data-stat="stl_pct">0.0</td><td class="right" data-stat="blk_pct">4.0</td><td class="right" data-stat="tov_pct">33.3</td><td class="right" data-stat="usg_pct">14.8</td><td class="right" data-stat="off_rtg">46</td><td class="right" data-stat="def_rtg">120</td><td class="right poptip" data-stat="bpm" data-tip="OBPM: -13.4&lt;br&gt; DBPM: -4.7&lt;br&gt; VORP: -5.3&lt;br&gt; &lt;em&gt;&lt;small&gt;VORP is prorated to 82 games&lt;/small&gt;&lt;/em&gt; ">-18.2</td></tr>
# <tr data-row="8"><th class="left" csk="Delk,Tony" data-append-csv="delkto01" data-stat="player" scope="row"><a href="/players/d/delkto01.html">Tony Delk</a></th><td class="right" csk="906" data-stat="mp">15:06</td><td class="right" data-stat="ts_pct">.800</td><td class="right" data-stat="efg_pct">.800</td><td class="right" data-stat="fg3a_per_fga_pct">.600</td><td class="right iz" data-stat="fta_per_fga_pct">.000</td><td class="right iz" data-stat="orb_pct">0.0</td><td class="right iz" data-stat="drb_pct">0.0</td><td class="right iz" data-stat="trb_pct">0.0</td><td class="right" data-stat="ast_pct">18.1</td><td class="right iz" data-stat="stl_pct">0.0</td><td class="right iz" data-stat="blk_pct">0.0</td><td class="right iz" data-stat="tov_pct">0.0</td><td class="right" data-stat="usg_pct">13.1</td><td class="right" data-stat="off_rtg">179</td><td class="right" data-stat="def_rtg">128</td><td class="right poptip" data-stat="bpm" data-tip="OBPM: 6.0&lt;br&gt; DBPM: -1.8&lt;br&gt; VORP: 2.0&lt;br&gt; &lt;em&gt;&lt;small&gt;VORP is prorated to 82 games&lt;/small&gt;&lt;/em&gt; ">4.2</td></tr>
# <tr data-row="9"><th class="left" csk="Addison,Rafael" data-append-csv="addisra01" data-stat="player" scope="row"><a href="/players/a/addisra01.html">Rafael Addison</a></th><td class="right" csk="786" data-stat="mp">13:06</td><td class="right" data-stat="ts_pct">.500</td><td class="right" data-stat="efg_pct">.500</td><td class="right iz" data-stat="fg3a_per_fga_pct">.000</td><td class="right iz" data-stat="fta_per_fga_pct">.000</td><td class="right iz" data-stat="orb_pct">0.0</td><td class="right" data-stat="drb_pct">8.6</td><td class="right" data-stat="trb_pct">4.1</td><td class="right" data-stat="ast_pct">24.4</td><td class="right" data-stat="stl_pct">3.9</td><td class="right iz" data-stat="blk_pct">0.0</td><td class="right iz" data-stat="tov_pct">0.0</td><td class="right" data-stat="usg_pct">24.2</td><td class="right" data-stat="off_rtg">125</td><td class="right" data-stat="def_rtg">116</td><td class="right poptip" data-stat="bpm" data-tip="OBPM: 0.1&lt;br&gt; DBPM: 1.4&lt;br&gt; VORP: 1.0&lt;br&gt; &lt;em&gt;&lt;small&gt;VORP is prorated to 82 games&lt;/small&gt;&lt;/em&gt; ">1.5</td></tr>
# <tr data-row="10"><th class="left" csk="Rose,Malik" data-append-csv="rosema01" data-stat="player" scope="row"><a href="/players/r/rosema01.html">Malik Rose</a></th><td class="right" csk="703" data-stat="mp">11:43</td><td class="right" data-stat="ts_pct">.258</td><td class="right" data-stat="efg_pct">.333</td><td class="right iz" data-stat="fg3a_per_fga_pct">.000</td><td class="right" data-stat="fta_per_fga_pct">.667</td><td class="right" data-stat="orb_pct">33.3</td><td class="right" data-stat="drb_pct">9.3</td><td class="right" data-stat="trb_pct">22.0</td><td class="right iz" data-stat="ast_pct">0.0</td><td class="right" data-stat="stl_pct">4.2</td><td class="right iz" data-stat="blk_pct">0.0</td><td class="right iz" data-stat="tov_pct">0.0</td><td class="right" data-stat="usg_pct">12.7</td><td class="right" data-stat="off_rtg">99</td><td class="right" data-stat="def_rtg">114</td><td class="right poptip" data-stat="bpm" data-tip="OBPM: -6.3&lt;br&gt; DBPM: -6.6&lt;br&gt; VORP: -2.7&lt;br&gt; &lt;em&gt;&lt;small&gt;VORP is prorated to 82 games&lt;/small&gt;&lt;/em&gt; ">-12.9</td></tr>
# <tr data-row="11"><th class="left" csk="Curry,Dell" data-append-csv="curryde01" data-stat="player" scope="row"><a href="/players/c/curryde01.html">Dell Curry</a></th><td class="center" colspan="16" data-stat="reason">Did Not Dress</td></tr>
# <tr data-row="12"><th class="left" csk="Smith,Tony" data-append-csv="smithto02" data-stat="player" scope="row"><a href="/players/s/smithto02.html">Tony Smith</a></th><td class="center" colspan="16" data-stat="reason">Did Not Dress</td></tr>
# </tbody><tfoot><tr data-row="13"><th class="left" data-stat="player" scope="row">Team Totals</th><td class="right" data-stat="mp">240</td><td class="right" data-stat="ts_pct">.523</td><td class="right" data-stat="efg_pct">.485</td><td class="right" data-stat="fg3a_per_fga_pct">.141</td><td class="right" data-stat="fta_per_fga_pct">.253</td><td class="right" data-stat="orb_pct">43.8</td><td class="right" data-stat="drb_pct">55.8</td><td class="right" data-stat="trb_pct">49.5</td><td class="right" data-stat="ast_pct">64.4</td><td class="right" data-stat="stl_pct">8.4</td><td class="right" data-stat="blk_pct">9.3</td><td class="right" data-stat="tov_pct">9.8</td><td class="right" data-stat="usg_pct">100.0</td><td class="right" data-stat="off_rtg">120.9</td><td class="right" data-stat="def_rtg">118.8</td><td class="right iz" data-stat="bpm"></td></tr>
# </tfoot>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div>
# <div><strong>Inactive: </strong><span><strong>PHI</strong> </span>None   <span><strong>CHH</strong> </span>None   </div>
# <div><strong>Officials: </strong><a href="/referees/garrero99r.html">Ron Garretson</a>, <a href="/referees/mccutmo99r.html">Monty McCutchen</a>, <a href="/referees/wundema99r.html">Mark Wunderlich</a></div>
# <div><strong>Attendance: </strong>24,042</div>
# </div>
# <!-- global.nonempty_tables_num: 3, table_count: 3 -->
# <!-- no Local/Partials/NoteBottom.tt2 -->
# <div class="section_wrapper" id="bottom_nav">
# <div class="section_heading"><span class="section_anchor" data-label="Team and League Schedules" data-no-inpage="1" id="inner_nav_bottom_link"></span><h2>Team and League Schedules</h2></div>
# <div class="section_content" id="bottom_nav_container">
# <p><a href="/boxscores/"><u>Apr 5, 1997 NBA Scores &amp; Boxes</u></a></p>
# <ul class="">
# <li><a href="/teams/PHI/1997_games.html"><u>Philadelphia 76ers Schedule</u></a></li>
# <li><a href="/teams/CHH/1997_games.html"><u>Charlotte Hornets Schedule</u></a></li>
# <li><a href="/leagues/NBA_1997_games.html"><u>1996-97 NBA Schedule &amp; Results</u></a></li>
# </ul></div></div>
# </body></html>
